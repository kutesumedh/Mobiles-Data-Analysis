# %% [markdown]
# ### Import Necessary Libraries
#
# * **selenium** : `selenium` is an open-source tool that automates web browsers for testing web applications and performing various web-based tasks
# * **BeautifulSoup** : `BeautifulSoup` is a Python library for parsing HTML and XML documents, enabling easy navigation, searching,etc
# * **requests** : The `requests` is a Python library used for making HTTP requests to interact with web services and retrieve web content.
# * **time** : The `time` library in Python provides functions for handling time-related tasks,like accessing current time, pausing execution, etc.
# * **numpy** : `numpy` is a fundamental Python library for numerical computing, providing support for large, multi-dimensional arrays and matrices, along with a wide range of mathematical functions to operate on them.
# * **pandas** : `pandas` is a powerful Python library for data manipulation and analysis, providing data structures like DataFrames and Series to efficiently handle and analyze structured data.
# * **re** : The `re` module in Python provides support for regular expressions, allowing for pattern matching, searching, and manipulating strings.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options

import requests
import time
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### Defining functions to extract/scrape data from webpage

# %%
# Function to get the name of mobile devices.
def get_name(new_soup):
    try:
        temp_name = new_soup.find('h1', attrs={'class': "h1_pro_head"})
        product_name = temp_name.text.strip()
    except:
        product_name = "N/A"
    return product_name

# Function to get the specification score of mobile devices.
def get_specsscore(new_soup):
    try:
        temp_specs_score = new_soup.find('div', class_=re.compile(r'^rating_box_new_list'))
        specs_score = temp_specs_score.text.strip()
    except:
        specs_score = "N/A"
    return specs_score

# Function to get the rating of mobile devices.
def get_rating(new_soup):
    try:
        temp_rating = new_soup.find('span', attrs={'class': 'ratpt'})
        rating = temp_rating.text.strip()
    except:
        rating = "N/A"
    return rating

# Function to get the price of mobile devices.
def get_price(new_soup):
    try:
        temp_price = new_soup.find('div', attrs={'class': "price_div"})
        price = temp_price.text.split('(onwards)')[0].replace('\nRs.\xa0 ', '').replace('\n ', '').strip()
    except:
        price = "N/A"
    return price

# Funtion to get specifications of the mobile
def get_specs(soup):
    specs = {}
    for spec_key in sample_phone_specs.keys():
        spec = soup.find(text=re.compile(spec_key))
        if spec:
            spec_value = spec.find_next().text.strip()
            specs[to_valid_variable_name(spec_key)] = spec_value
        else:
            specs[to_valid_variable_name(spec_key)] = 'N/A'
    return specs

# Function to get the RAM of mobile devices.
def get_ram(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*RAM\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the screen resolution of mobile devices.
def get_resolution(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Resolution\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the refresh rate of mobile devices.
def get_refresh_rate(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Refresh\s*Rate\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the display type of mobile devices.    
def get_displaytype(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Display\s*Type\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the screen size of mobile devices.
def get_screensize(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Screen\s*Size\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the processor of mobile devices.
def get_processor(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Processor\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the rear camera information of mobile devices.
def get_Rear_Camera(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Rear\s*Camera\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the front camera information of mobile devices.
def get_front_camera(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Front\s*Camera\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the battery of mobile devices.
def get_battery(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Battery\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the display of mobile devices.
def get_display(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Display\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the operating system of mobile devices.
def get_os(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Operating\s*System\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the RAM-type of mobile devices.
def get_ramtype(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*RAM\s*TYPE\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the chipset information of mobile devices.
def get_Chipset(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Chipset\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the internal memory of mobile devices.
def get_internal_memory(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Internal\s*Memory\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the color of mobile devices.
def get_color(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Color\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# Function to get the weight of mobile devices.
def get_Weight(soup):
    try:
        spec_divs = soup.select("div.spec_box")
        for div in spec_divs:
            tr_elements = div.find_all('tr')
            for tr in tr_elements:
                td_elements = tr.find_all('td')
                if len(td_elements) >= 2:
                    first_td_text = td_elements[0].get_text(strip=True)
                    second_td_text = td_elements[1].get_text(strip=True)
                    if re.search(r'^\s*Weight\s*$', first_td_text, re.IGNORECASE):
                        return second_td_text
    except:
        return "N/A"

# %% [markdown]
# ### Python dictionary named *`HEADERS`* that contains various HTTP headers commonly used in web requests.

# %%
HEADERS = ({
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en-US,en;q=0.8',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
}
)

# %% [markdown]
# ###  Web scraping using *Selenium* and *BeautifulSoup* in Python

# %%
# Setting up Chrome WebDriver with Custom Options:
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--disable-gpu")  
chrome_options.add_argument("--headless")  

chromedriver_path = r"C:\Users\Shashank\Downloads\chromedriver-win64\chromedriver.exe"  
driver = webdriver.Chrome(service=Service(chromedriver_path), options=chrome_options)

# Defining URL:
URL = "https://www.91mobiles.com/phonefinder.php"
driver.get(URL)

# Initializing Lists:
names = []
specs_scores = []
ratings = []
prices = []
ram = []
ramtype = []
resolution = []
refresh_rate = []
display_type = []
screen_size = []
chipset = []
cpu = []
architecture = []
fabrication = []
graphics = []
pixel_density = []
quick_charging = []
type_c = []
internal_memory = []
expandable_memory = []
sim_slot = []
wifi = []
wifi_features = []
bluetooth = []
gps = []
nfc = []
radio = []
fingerprint_sensor = []

# Setting up a Requests Session:
page = 1
session = requests.Session()
session.max_redirects = 10000  

# Main Scraping Loop. Scraping Data from Each Page. Handling Errors and Pagination:
while True:
    print(f"Processing page {page}")

    
    while True:
        try:
            
            WebDriverWait(driver, 3).until(EC.visibility_of_element_located((By.CLASS_NAME, "listing-btns4")))
            print("Element with class name 'listing-btns4' is visible on the screen.")
            break  
        except Exception as e:
            
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            print("Scrolling...")

    try:
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, "html.parser")

        links = soup.find_all("a", class_='hover_blue_link name gaclick')
        links_list = [link.get('href') for link in links]

        HEADERS = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

        for link in links_list:
            full_url = "https://www.91mobiles.com/" + link
            try:
                response = session.get(full_url, headers=HEADERS, allow_redirects=True)
                new_soup = BeautifulSoup(response.content, "html.parser")
                names.append(get_name(new_soup))
                specs_scores.append(get_specsscore(new_soup))
                ratings.append(get_rating(new_soup))
                prices.append(get_price(new_soup))
                ram.append(get_ram(new_soup))
                ramtype.append(get_ramtype(new_soup))
                resolution.append(get_resolution(new_soup))
                refresh_rate.append(get_refresh_rate(new_soup))
                display_type.append(get_displaytype(new_soup))
                screen_size.append(get_screensize(new_soup))
                chipset.append(get_Chipset(new_soup))
                cpu.append(get_CPU(new_soup))
                architecture.append(get_architecture(new_soup))
                fabrication.append(get_Fabrication(new_soup))
                graphics.append(get_graphics(new_soup))
                pixel_density.append(get_pixel_density(new_soup))
                quick_charging.append(get_quick_charging(new_soup))
                type_c.append(get_type_c(new_soup))
                internal_memory.append(get_internal_memory(new_soup))
                expandable_memory.append(get_expandable_Memory(new_soup))
                sim_slot.append(get_sim_slot(new_soup))
                wifi.append(get_wifi(new_soup))
                wifi_features.append(get_wifi_features(new_soup))
                bluetooth.append(get_bluetooth(new_soup))
                gps.append(get_gps(new_soup))
                nfc.append(get_nfc(new_soup))
                radio.append(get_radio(new_soup))
                fingerprint_sensor.append(get_fingerprint(new_soup))
            except requests.exceptions.TooManyRedirects as e:
                print(f"Too many redirects for URL: {full_url}")
            except Exception as e:
                print(f"Error fetching URL {full_url}: {e}")

        try:
            next_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "listing-btns4")))
            next_button.click()
            time.sleep(4)  
            page += 1
        except Exception as e:
            print("No more pages or error occurred while clicking next button:", e)
            break  

    except Exception as e:
        print(f"Error on page {page}: {e}")
        break

# Quitting the WebDriver:
driver.quit()
# Out:
# Processing page 1
# Scrolling...
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 2
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 3
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 4
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 5
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 6
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 7
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 8
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 9
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 10
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 11
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 12
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 13
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 14
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 15
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 16
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 17
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 18
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 19
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 20
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 21
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 22
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 23
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 24
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 25
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 26
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 27
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 28
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 29
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 30
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 31
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 32
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 33
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 34
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 35
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 36
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 37
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 38
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 39
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 40
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 41
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 42
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 43
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 44
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 45
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 46
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 47
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 48
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 49
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 50
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 51
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 52
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 53
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 54
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 55
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 56
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 57
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 58
# Element with class name 'listing-btns4' is visible on the screen.
# Error fetching URL https://www.91mobiles.com//tecno-spark-go-price-in-india: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# Processing page 59
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 60
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 61
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 62
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 63
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 64
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 65
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 66
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 67
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 68
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 69
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 70
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 71
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 72
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 73
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 74
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 75
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 76
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 77
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 78
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 79
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 80
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 81
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 82
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 83
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 84
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 85
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 86
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 87
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 88
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 89
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 90
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 91
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 92
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 93
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 94
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 95
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 96
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 97
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 98
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 99
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 100
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 101
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 102
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 103
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 104
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 105
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 106
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 107
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 108
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 109
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 110
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 111
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 112
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 113
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 114
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 115
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 116
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 117
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 118
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 119
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 120
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 121
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 122
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 123
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 124
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 125
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 126
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 127
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 128
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 129
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 130
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 131
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 132
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 133
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 134
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 135
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 136
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 137
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 138
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 139
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 140
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 141
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 142
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 143
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 144
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 145
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 146
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 147
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 148
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 149
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 150
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 151
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 152
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 153
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 154
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 155
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 156
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 157
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 158
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 159
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 160
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 161
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 162
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 163
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 164
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 165
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 166
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 167
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 168
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 169
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 170
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 171
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 172
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 173
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 174
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 175
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 176
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 177
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 178
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 179
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 180
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 181
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 182
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 183
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 184
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 185
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 186
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 187
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 188
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 189
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 190
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 191
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 192
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 193
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 194
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 195
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 196
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 197
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 198
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 199
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 200
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 201
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 202
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 203
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 204
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 205
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 206
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 207
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 208
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 209
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 210
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 211
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 212
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 213
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 214
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 215
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 216
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 217
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 218
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 219
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 220
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 221
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 222
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 223
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 224
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 225
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 226
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 227
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 228
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 229
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 230
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 231
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 232
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 233
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 234
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 235
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 236
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 237
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 238
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 239
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 240
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 241
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 242
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 243
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 244
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 245
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 246
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 247
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 248
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 249
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 250
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 251
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 252
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 253
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 254
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 255
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 256
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 257
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 258
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 259
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 260
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 261
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 262
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 263
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 264
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 265
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 266
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 267
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 268
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 269
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 270
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 271
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 272
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 273
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 274
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 275
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 276
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 277
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 278
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 279
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 280
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 281
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 282
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 283
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 284
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 285
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 286
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 287
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 288
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 289
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 290
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 291
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 292
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 293
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 294
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 295
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 296
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 297
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 298
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 299
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 300
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 301
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 302
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 303
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 304
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 305
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 306
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 307
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 308
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 309
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 310
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 311
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 312
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 313
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 314
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 315
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 316
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 317
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 318
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 319
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 320
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 321
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 322
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 323
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 324
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 325
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 326
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 327
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 328
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 329
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 330
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 331
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 332
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 333
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 334
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 335
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 336
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 337
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 338
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 339
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 340
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 341
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 342
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 343
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 344
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 345
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 346
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 347
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 348
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 349
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 350
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 351
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 352
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 353
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 354
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 355
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 356
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 357
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 358
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 359
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 360
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 361
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 362
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 363
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 364
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 365
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 366
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 367
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 368
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 369
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 370
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 371
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 372
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 373
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 374
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 375
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 376
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 377
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 378
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 379
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 380
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 381
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 382
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 383
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 384
# Element with class name 'listing-btns4' is visible on the screen.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Processing page 385
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 386
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 387
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 388
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 389
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 390
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 391
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 392
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 393
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 394
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 395
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 396
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 397
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 398
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 399
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 400
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 401
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 402
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 403
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 404
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 405
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 406
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 407
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 408
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 409
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 410
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 411
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 412
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 413
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 414
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 415
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 416
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 417
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 418
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 419
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 420
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 421
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 422
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 423
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 424
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 425
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 426
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 427
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 428
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 429
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 430
# Element with class name 'listing-btns4' is visible on the screen.
# Processing page 431
# Element with class name 'listing-btns4' is visible on the screen.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 96
#      94 full_url = "https://www.91mobiles.com/" + link
#      95 try:
# ---> 96     response = session.get(full_url, headers=HEADERS, allow_redirects=True)
#      97     new_soup = BeautifulSoup(response.content, "html.parser")
#      98     names.append(get_name(new_soup))
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Creating the DataFrame using initialized lists which contains scraped data

# %%
df = pd.DataFrame({
    'Name': names,
    'Specs Score': specs_scores,
    'Rating': ratings,
    'Price': prices,
    'RAM': ram,
    'RAM Type': ramtype,
    'Resolution': resolution,
    'Refresh Rate': refresh_rate,
    'Display Type': display_type,
    'Screen Size': screen_size,
    'Chipset': chipset,
    'CPU': cpu,
    'Architecture': architecture,
    'Fabrication': fabrication,
    'Graphics': graphics,
    'Pixel Density': pixel_density,
    'Quick Charging': quick_charging,
    'Type-C': type_c,
    'Internal Memory': internal_memory,
    'Expandable Memory': expandable_memory,
    'SIM Slot': sim_slot,
    'WiFi': wifi,
    'WiFi Features': wifi_features,
    'Bluetooth': bluetooth,
    'GPS': gps,
    'NFC': nfc,
    'Radio': radio,
    'Fingerprint Sensor': fingerprint_sensor
})

# %% [markdown]
# ### Viewing the created dataframe

# %%
df
# Out:
#                      Name Specs Score   Rating                     Price  \
# 0                  AGM A7         50%      N/A  15,271(Last Known Price)
# 1                  AGM M1         86%      N/A   5,893(Last Known Price)
# 2              UHANS U300         68%      N/A  20,402(Last Known Price)
# 3            UHANS Note 4         65%      N/A  14,745(Last Known Price)
# 4                 Yuho H1         86%      N/A   8,999(Last Known Price)
# ...                   ...         ...      ...                       ...
# 5122   VOX Mobile VGS-603         45%  4.1 / 5   1,609(Last Known Price)
# 5123           Onida F950         86%      N/A   1,099(Last Known Price)
# 5124           HTC Tattoo         45%  1.9 / 5  22,900(Last Known Price)
# 5125          Karbonn K20         45%    5 / 5   1,489(Last Known Price)
# 5126  Samsung S5620 Monte         45%  4.3 / 5  10,200(Last Known Price)
#
#          RAM RAM Type              Resolution Refresh Rate Display Type  \
# 0       2 GB     None              480x800 px         None          TFT
# 1     128 MB     None              176x220 px         None          TFT
# 2       4 GB     None  1080x1920 px (FULL HD)         None      IPS LCD
# 3       3 GB     None        720x1280 px (HD)         None      IPS LCD
# 4       2 GB     None        720x1280 px (HD)         None      IPS LCD
# ...      ...      ...                     ...          ...          ...
# 5122    None     None        240 x 400 pixels         None          LCD
# 5123    None     None        176 x 220 pixels         None          LCD
# 5124  256 MB     None        240 x 320 pixels         None          LCD
# 5125    None     None        320 x 240 pixels         None         None
# 5126    None     None        240 x 400 pixels         None          LCD
#
#                 Screen Size  ...  Internal Memory  Expandable Memory  \
# 0       4 inches (10.16 cm)  ...  16 GBVery Good▾   Yes, Up to 32 GB
# 1        2 inches (5.08 cm)  ...            64 MB   Yes, Up to 32 GB
# 2     5.5 inches (13.97 cm)  ...  32 GBExcellent▾  Yes, Up to 128 GB
# 3     5.5 inches (13.97 cm)  ...  32 GBExcellent▾  Yes, Up to 128 GB
# 4        5 inches (12.7 cm)  ...            16 GB   Yes, Up to 64 GB
# ...                     ...  ...              ...                ...
# 5122     3 inches (7.62 cm)  ...             None    Yes, Up to 2 GB
# 5123   1.9 inches (4.83 cm)  ...             None    Yes, Up to 2 GB
# 5124   2.8 inches (7.11 cm)  ...           512 MB                Yes
# 5125    2.4 inches (6.1 cm)  ...           259 KB    Yes, Up to 8 GB
# 5126     3 inches (7.62 cm)  ...           227 MB   Yes, Up to 16 GB
#
#                SIM Slot                           WiFi  \
# 0     Dual SIM, GSM+GSM    Yes, Wi-Fi 4 (802.11 b/g/n)
# 1     Dual SIM, GSM+GSM                           None
# 2     Dual SIM, GSM+GSM    Yes, Wi-Fi 4 (802.11 b/g/n)
# 3     Dual SIM, GSM+GSM  Yes, Wi-Fi 4 (802.11 a/b/g/n)
# 4     Dual SIM, GSM+GSM  Yes, Wi-Fi 4 (802.11 a/b/g/n)
# ...                 ...                            ...
# 5122  Dual SIM, GSM+GSM                             No
# 5123    Single SIM, GSM                             No
# 5124    Single SIM, GSM    Yes, Wi-Fi 3 (802.11 a/b/g)
# 5125  Dual SIM, GSM+GSM                             No
# 5126    Single SIM, GSM      Yes, Wi-Fi 3 (802.11 b/g)
#
#                      WiFi Features  Bluetooth             GPS   NFC     Radio  \
# 0                   Mobile Hotspot  Yes, v4.0  Yes with A-GPS  None      None
# 1                             None  Yes, v2.1            None  None      None
# 2                   Mobile Hotspot  Yes, v4.0  Yes with A-GPS  None       Yes
# 3     Wi-Fi Direct, Mobile Hotspot  Yes, v4.0  Yes with A-GPS  None      None
# 4                             None        Yes             Yes    No      None
# ...                            ...        ...             ...   ...       ...
# 5122                          None    Yes, v2            None  None       Yes
# 5123                          None        Yes            None  None      None
# 5124                          None    Yes, v2  Yes with A-GPS  None  Yes, RDS
# 5125                          None        Yes            None  None       Yes
# 5126                          None  Yes, v2.1            None  None  Yes, RDS
#
#      Fingerprint Sensor
# 0                    No
# 1                  None
# 2                   Yes
# 3                   Yes
# 4                  None
# ...                 ...
# 5122               None
# 5123               None
# 5124               None
# 5125               None
# 5126               None
#
# [5127 rows x 28 columns]

# %% [markdown]
# ### Exporting the DataFrame into csv(Comma seperated file).

# %%
df.to_csv("mobiles_data.csv",index=False)
